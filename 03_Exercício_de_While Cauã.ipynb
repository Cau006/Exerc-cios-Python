# %% [markdown]
# # Exercícios
#
# ## 1. Input até o usuário parar
#
# Vamos criar um sistema de vendas. Nosso programa deve registrar os produtos e as quantidades (2 inputs) e adicionar em uma lista.
#
# O programa deve continuar rodando até o input ser vazio, ou seja, o usuário apertar enter sem digitar nenhum produto ou quantidade.
#
# Ao final do programa, ele deve printar todos os produtos e quantidades vendidas.
#
# Obs: Caso queira, para o print ficar mais visual, pode usar o join para cada item ser printado em uma linha.
# Sugestão para sua lista de produtos vendidos:

# %% [raw]
# vendas = [
#     ['maçã', 5],
#     ['banana', 15],
#     ['azeite', 1],
#     ['vinho', 3],
# ]

# %%
vnds = []
prods = []

prod = input("Para cancelar o registro de um novo produto, basta digitar *. Registre o nome do produto: ")
vnd = input("Para cancelar o registro de um novo produto, basta digitar *. Registre o número de vendas: ")

while prod != "*" and vnd != "*":
    prods.append(prod)
    vnds.append(vnd)

    prod = input("Para cancelar o registro de um novo produto, basta digitar *. Registre o nome do produto: ")
    vnd = input("Para cancelar o registro de um novo produto, basta digitar *. Registre o número de vendas: ")

if len(prods) == 0:
    print("Os produtos foram cancelados. Nenhum registro realizado.")
else:
    print("Registro finalizado.")
    print("Os produtos cadastrados foram: {}".format(prods))
    print("O número de vendas registradas foi: {}".format(vnds))
# Out:
# Para cancelar o registro de um novo produto, basta digitar *. Registre o nome do produto: *
# Para cancelar o registro de um novo produto, basta digitar *. Registre o número de vendas: *
# Os produtos foram cancelados. Nenhum registro realizado.

# %% [markdown]
# ### Obs: Podemos fazer o While de 2 maneiras:
#
# 1. While com a condição que finalize o programa
# 2. While rodando para sempre, mas com uma condição dentro do while que dê um break no código.
#
# Vamos mostrar as 2 opções
